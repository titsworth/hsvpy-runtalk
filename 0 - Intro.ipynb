# %% [markdown]
# # Welcome to hsv.py!
#
# <img style="float: right" src="images/hsvpy.png" />
#
# This is our seconds meeting (first talk). Thanks for coming!
#
# # Thanks To Our Sponsors!
#
# ## Metabahn
# ###*empowering the dev community / making it more interesting*
#
# <img style="float: right" src="images/metabahn.png" width="300" />
#
# Metabahn is a web and mobile development company based in Huntsville.
#
# We seek to empower the developer community in an effort to help create a culture of innovation in our city.
#
# # O'Reilly
#
# <img style="float: right" src="images/oreilly.png" />
#
# O'Reilly has provided us with some great books, stickers, and coupons to give away at our meetings.
#
# For this we are very greatful!
#
# #Who I am I?
#
# <img style="float: right" src="images/george.jpg" width="200" />
#
# ## George Titsworth
#
# ### [@titsworth](http://twitter.com/titsworth)
#
# Software Developer and Data Analyst
#
# Python Enthusiast
#
# Part-time Runner
#
# ## A runner you say?
#
# I know what you're thinking - *"You don't look like a runner"*
#
# ####To that I have to say:

# %%
from IPython.display import Image
Image("images/bulking.png")

# %% [markdown]
# ### Ok, let's be honest

# %%
Image("images/bulking_lie.jpg")
